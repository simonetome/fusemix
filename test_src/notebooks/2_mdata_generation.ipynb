# %%
from pathlib import Path
import os,sys
import pickle
import pandas as pd

from tqdm.notebook import tqdm
import importlib

sys.path.insert(0, str(Path().resolve().parents[1]))
import fusemix.pipeline as pipeline

# %%
def load_dataset(id):
    with open("../../test_data/fetched/dataset_"+str(id)+".pkl", "rb") as input:
        file = pickle.load(input)
    return file

# %%
ids = pd.read_csv("../../test_output/datasets_analysis.csv")['Id']

loaded_data = {}
for id in ids: loaded_data[id] = load_dataset(id = id)

# %%
n_runs = 10

md_param_grid = {
    'props': [0.75,1.],
    'mf_proportions': [0.5,0.75],
    'mnar_proportions': [0.,0.25,0.5]
}

# %%
for id in ids:
    # create directory for dataset id in test_data/missing_data
    directory = "../../test_data/missing_data/"+str(id)
    if not os.path.exists(directory):
        os.makedirs(directory)
    # create directory for dataset id in test_data/missing_data/parameters
    for prop in md_param_grid['props']:
        for mf_proportion in md_param_grid['mf_proportions']:
            for mnar_proportion in md_param_grid['mnar_proportions']:
                directory = "../../test_data/missing_data/"+str(id)+"/"+str(prop)+"_"+str(mf_proportion)+"_"+str(mnar_proportion)
                if not os.path.exists(directory):
                    os.makedirs(directory)

# %% [markdown]
# ### Generate amputations

# %%
for id in tqdm(ids):

    data_ = loaded_data[id]
    print(data_['X_complete'].shape)
    print(id)
    for prop in tqdm(md_param_grid['props']):
        for mf_proportion in tqdm(md_param_grid['mf_proportions']):
            for mnar_proportion in tqdm(md_param_grid['mnar_proportions']):
                
                directory = "../../test_data/missing_data/"+str(id)+"/"+str(prop)+"_"+str(mf_proportion)+"_"+str(mnar_proportion)
                
                for seed in tqdm(range(n_runs)):
                    print(seed)
                    cfg = pipeline.DataPipelineConfig(seed=seed,
                                                      prop=prop,
                                                      mnar_freq=mnar_proportion,
                                                      mf_proportion=mf_proportion,
                                                      complete_data=data_['X_complete'],
                                                      num_classes=data_['num_classes'],
                                                      verbose=False,
                                                      target=data_['y_complete'])
                    pipeline_ = pipeline.PipelineDataGeneration(cfg)
                    pipeline_.run()
                    
                    directory = "../../test_data/missing_data/"+str(id)+"/"+str(prop)+"_"+str(mf_proportion)+"_"+str(mnar_proportion)
                    with open(directory+"/data_pipeline_"+str(seed)+".pkl", 'wb') as f:  
                        pickle.dump(pipeline_, f)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# (195, 20)
# 174
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-30 16:12:04,162 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,170 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,205 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,224 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,242 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,253 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,300 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,302 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,327 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,343 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,344 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,350 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 1
# 2
# 3
# 4
# 2025-10-30 16:12:04,359 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,365 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,386 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,390 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,423 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,459 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,463 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,484 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,496 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,498 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,532 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,541 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 5
# 6
# 7
# 8
# 9
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-30 16:12:04,569 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,576 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 2025-10-30 16:12:04,607 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,625 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,642 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,650 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,670 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,671 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,692 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,707 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,708 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,714 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,722 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,727 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,745 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,749 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 1
# 2
# 3
# 4
# 5
# 2025-10-30 16:12:04,779 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 6
# 2025-10-30 16:12:04,812 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,815 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,838 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,850 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,851 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,882 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,891 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 7
# 8
# 9
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-30 16:12:04,921 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,927 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:04,957 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,971 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 1
# 2025-10-30 16:12:04,984 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:04,992 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,010 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2
# 3
# 2025-10-30 16:12:05,012 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,030 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,045 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,047 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,051 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,058 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,062 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,075 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,079 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,108 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 4
# 5
# 6
# 2025-10-30 16:12:05,134 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,137 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,152 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,162 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,163 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 7
# 8
# 2025-10-30 16:12:05,197 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,204 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 9
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-30 16:12:05,234 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 0
# 2025-10-30 16:12:05,249 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,255 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,277 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,294 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,298 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,302 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,309 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,316 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,321 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 1
# 2
# 2025-10-30 16:12:05,335 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-30 16:12:05,339 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,347 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05,363 [WARNING] Subset for pattern 10 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-30 16:12:05