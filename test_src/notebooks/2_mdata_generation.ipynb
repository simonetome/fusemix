# %%
from pathlib import Path
import os,sys
import pickle
import pandas as pd

from tqdm.notebook import tqdm
import importlib

sys.path.insert(0, str(Path().resolve().parents[1]))
import fusemix.pipeline as pipeline

# %%
def load_dataset(id):
    with open("../../test_data/fetched/dataset_"+str(id)+".pkl", "rb") as input:
        file = pickle.load(input)
    return file

# %%
ids = pd.read_csv("../../test_output/datasets_analysis.csv")['Id']

loaded_data = {}
for id in ids: loaded_data[id] = load_dataset(id = id)

# %%
n_runs = 10

md_param_grid = {
    'props': [0.75,1.],
    'mf_proportions': [0.5,0.75],
    'mnar_proportions': [0.,0.25,0.5]
}
"""
md_param_grid = {
    'props': [1.],
    'mf_proportions': [0.75],
    'mnar_proportions': [0.5]
}
"""
# Out:
# "\nmd_param_grid = {\n    'props': [1.],\n    'mf_proportions': [0.75],\n    'mnar_proportions': [0.5]\n}\n"

# %%
for id in ids:
    # create directory for dataset id in test_data/missing_data
    directory = "../../test_data/missing_data/"+str(id)
    if not os.path.exists(directory):
        os.makedirs(directory)
    # create directory for dataset id in test_data/missing_data/parameters
    for prop in md_param_grid['props']:
        for mf_proportion in md_param_grid['mf_proportions']:
            for mnar_proportion in md_param_grid['mnar_proportions']:
                directory = "../../test_data/missing_data/"+str(id)+"/"+str(prop)+"_"+str(mf_proportion)+"_"+str(mnar_proportion)
                if not os.path.exists(directory):
                    os.makedirs(directory)

# %% [markdown]
# ### Generate amputations

# %%
data_ = loaded_data[174]
print(data_['X_complete'].shape)
print(data_['y_complete'].shape)
data_['num_classes']
# Out:
# (195, 20)
# (195, 1)
# 2

# %%
data_['X_complete']['MDVP_Jitter']
# Out:
# 0      0.00784
# 1      0.00968
# 2      0.01050
# 3      0.00997
# 4      0.01284
#         ...
# 190    0.00459
# 191    0.00564
# 192    0.01360
# 193    0.00740
# 194    0.00567
# Name: MDVP_Jitter, Length: 195, dtype: float64

# %%
for id in tqdm(ids):

    data_ = loaded_data[id]
    print(data_['X_complete'].shape)
    print(id)
    for prop in tqdm(md_param_grid['props']):
        for mf_proportion in tqdm(md_param_grid['mf_proportions']):
            for mnar_proportion in tqdm(md_param_grid['mnar_proportions']):
                
                directory = "../../test_data/missing_data/"+str(id)+"/"+str(prop)+"_"+str(mf_proportion)+"_"+str(mnar_proportion)
                
                for seed in tqdm(range(n_runs)):
                    print(seed)
                    cfg = pipeline.DataPipelineConfig(seed=seed,
                                                      prop=prop,
                                                      mnar_freq=mnar_proportion,
                                                      mf_proportion=mf_proportion,
                                                      complete_data=data_['X_complete'],
                                                      num_classes=data_['num_classes'],
                                                      verbose=False,
                                                      target=data_['y_complete'])
                    pipeline_ = pipeline.PipelineDataGeneration(cfg)
                    pipeline_.run()
                    
                    directory = "../../test_data/missing_data/"+str(id)+"/"+str(prop)+"_"+str(mf_proportion)+"_"+str(mnar_proportion)
                    with open(directory+"/data_pipeline_"+str(seed)+".pkl", 'wb') as f:  
                        pickle.dump(pipeline_, f)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# (195, 20)
# 174
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-27 17:11:57,621 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,631 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,686 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,715 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,733 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,744 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,770 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,772 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,792 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 1
# 2
# 3
# 2025-10-27 17:11:57,809 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 4
# 2025-10-27 17:11:57,810 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,817 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,824 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,831 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,851 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,855 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,886 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,921 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,924 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,945 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,957 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:57,959 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:57,993 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,003 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 5
# 6
# 7
# 8
# 9
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-27 17:11:58,036 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,046 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 2025-10-27 17:11:58,080 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,101 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,129 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,144 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,177 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,179 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,200 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,214 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,216 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,221 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,229 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,235 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 1
# 2
# 3
# 4
# 2025-10-27 17:11:58,252 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,256 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 5
# 6
# 2025-10-27 17:11:58,288 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,322 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,326 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,348 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,360 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,362 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,396 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,405 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 7
# 8
# 9
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-27 17:11:58,437 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,442 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 2025-10-27 17:11:58,465 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,479 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,492 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,501 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,521 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 1
# 2
# 3
# 2025-10-27 17:11:58,523 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,545 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,561 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,564 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,569 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,575 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,579 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,593 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,597 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,629 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 4
# 5
# 6
# 7
# 2025-10-27 17:11:58,652 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,656 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,671 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,680 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,681 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,715 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,721 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 8
# 9
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-27 17:11:58,749 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,755 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,759 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 2025-10-27 17:11:58,775 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,811 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,815 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,818 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,828 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,834 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,839 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,851 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,855 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,862 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,877 [WARNING] Subset for pattern 10 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 1
# 2
# 2025-10-27 17:11:58,893 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,895 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,898 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,904 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,908 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,911 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,914 [WARNING] Subset for pattern 6 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,921 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,925 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,931 [WARNING] Subset for pattern 11 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,940 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,941 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,948 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 3
# 4
# 2025-10-27 17:11:58,980 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:58,984 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:58,987 [WARNING] Candidates for pattern 1 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:11:59,004 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 5
# 2025-10-27 17:11:59,020 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,033 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,044 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,056 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,073 [WARNING] Subset for pattern 6 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,084 [WARNING] Subset for pattern 10 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 6
# 7
# 8
# 2025-10-27 17:11:59,095 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,096 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,131 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,132 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,135 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,143 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,163 [WARNING] Subset for pattern 12 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 9
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-27 17:11:59,172 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,179 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 2025-10-27 17:11:59,182 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,197 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,210 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,214 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,217 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 1
# 2025-10-27 17:11:59,225 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,231 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,237 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,250 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,253 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,261 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,277 [WARNING] Subset for pattern 10 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,293 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,295 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,298 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,304 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,308 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,311 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,314 [WARNING] Subset for pattern 6 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,320 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,323 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2
# 3
# 2025-10-27 17:11:59,336 [WARNING] Subset for pattern 11 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,355 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,357 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,363 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 4
# 2025-10-27 17:11:59,396 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,400 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,402 [WARNING] Candidates for pattern 1 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 5
# 2025-10-27 17:11:59,416 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,431 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,451 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 6
# 2025-10-27 17:11:59,462 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,478 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,498 [WARNING] Subset for pattern 6 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,510 [WARNING] Subset for pattern 10 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,528 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,531 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 7
# 8
# 2025-10-27 17:11:59,584 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,586 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,589 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,596 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 9
# 2025-10-27 17:11:59,619 [WARNING] Subset for pattern 12 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-27 17:11:59,629 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,638 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 0
# 2025-10-27 17:11:59,642 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,660 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,672 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,676 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,679 [WARNING] Subset for pattern 2 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 1
# 2025-10-27 17:11:59,686 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,691 [WARNING] Subset for pattern 7 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,697 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,711 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,714 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,722 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,736 [WARNING] Subset for pattern 10 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,749 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:11:59,751 [WARNING] Subset for pattern 0 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,754 [WARNING] Subset for pattern 1 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,759 [WARNING] Subset for pattern 3 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,762 [WARNING] Subset for pattern 4 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,765 [WARNING] Subset for pattern 5 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,768 [WARNING] Subset for pattern 6 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,773 [WARNING] Subset for pattern 8 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,775 [WARNING] Subset for pattern 9 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2025-10-27 17:11:59,781 [WARNING] Subset for pattern 11 is small. Too many patterns can result in subsets with 0 or few candidates. Subsets with 0 candidates will be skipped. Under MCAR, subsets with few candidates will be amputed as normal.
# 2
# 3
# 2025-10-27 17:11:59,787 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# ...
# 2025-10-27 17:12:52,473 [WARNING] Candidates for pattern 24 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,483 [WARNING] Candidates for pattern 28 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,488 [WARNING] Candidates for pattern 30 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,493 [WARNING] Candidates for pattern 32 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,498 [WARNING] Candidates for pattern 34 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,503 [WARNING] Candidates for pattern 36 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# C:\Users\simone\Documents\GitHub\fusemix\libs\pyampute\pyampute\ampute.py:402: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   data_group = stats.zscore(data_group)
# 2025-10-27 17:12:52,523 [WARNING] Candidates for pattern 43 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,532 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible data\shift_lookup.csv is missing, in the wrong location, or corrupted. Try rerunning scripts/generate_shift_lookup_table.py to regenerate the lookup table.
# 2025-10-27 17:12:52,534 [WARNING] Binary variables (at indices [ 5  9 11]) are indicated to be used in amputation (they are weighted and will be used to calculate the weighted sum score under MAR, MNAR, or MAR+MNAR). This can result in a subset with candidates that all have the same (or almost the same) weighted sum scores.
# 2025-10-27 17:12:52,545 [WARNING] Candidates for pattern 3 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,548 [WARNING] Candidates for pattern 4 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,553 [WARNING] Candidates for pattern 6 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,556 [WARNING] Candidates for pattern 7 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,558 [WARNING] Candidates for pattern 8 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,566 [WARNING] Candidates for pattern 11 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,576 [WARNING] Candidates for pattern 15 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,580 [WARNING] Candidates for pattern 16 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,585 [WARNING] Candidates for pattern 18 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,588 [WARNING] Candidates for pattern 19 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,590 [WARNING] Candidates for pattern 20 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,596 [WARNING] Candidates for pattern 22 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,601 [WARNING] Candidates for pattern 24 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,608 [WARNING] Candidates for pattern 27 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,611 [WARNING] Candidates for pattern 28 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,618 [WARNING] Candidates for pattern 30 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,629 [WARNING] Candidates for pattern 32 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,639 [WARNING] Candidates for pattern 34 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,648 [WARNING] Candidates for pattern 37 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,658 [WARNING] Candidates for pattern 38 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,662 [WARNING] Candidates for pattern 39 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,665 [WARNING] Candidates for pattern 40 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 2025-10-27 17:12:52,678 [WARNING] Candidates for pattern 43 all have almost the same weighted sum scores. It is possible this is due to the use of binary variables in amputation. This creates problems when using the sigmoid function for the score_to_probability_func. Currently our solution is as follows: if there is just one candidate with a sum score 0, we will ampute it. If there is one candidate with a nonzero sum score, or multiple candidates with the same score, we evenly apply as if MCAR.
# 9
